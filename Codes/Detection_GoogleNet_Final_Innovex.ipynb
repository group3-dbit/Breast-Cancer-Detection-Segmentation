# %%
import json
import math
import os
 
import cv2
from PIL import Image
import numpy as np
from keras import layers
#from keras.applications import MobileNet, DenseNet201, InceptionV3, NASNetLarge, InceptionResNetV2, NASNetMobile
from keras.callbacks import Callback, ModelCheckpoint, ReduceLROnPlateau, TensorBoard
from keras.preprocessing.image import ImageDataGenerator
from keras.utils.np_utils import to_categorical
from keras.models import Sequential
from keras.optimizers import Adam
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import cohen_kappa_score, accuracy_score
import scipy
from tqdm import tqdm
import tensorflow as tf
from keras import backend as K
import gc
from functools import partial
from sklearn import metrics
from collections import Counter
import json
import itertools
from skimage.transform import resize
 
 
# %matplotlib inline

# %%
#Transfer 'png' images to an array IMG
def Dataset_loader(DIR, RESIZE, sigmaX=10):
    IMG = []
    read = lambda imname: np.asarray(Image.open(imname))/255
    for IMAGE_NAME in tqdm(os.listdir(DIR)):
        PATH = os.path.join(DIR,IMAGE_NAME)
        _, ftype = os.path.splitext(PATH)
        if ftype == ".png":
            img = read(PATH)
           
            img = resize(img, (RESIZE,RESIZE,3))
           
            IMG.append(np.array(img))
    return IMG

benign_train = np.array(Dataset_loader('/content/drive/MyDrive/ddsm/Benign/original/CC_Benign',224))
malign_train = np.array(Dataset_loader('/content/drive/MyDrive/ddsm/Cancer/original',224))
benign_test = np.array(Dataset_loader('/content/drive/MyDrive/Minita/image_val',224))
malign_test = np.array(Dataset_loader('/content/drive/MyDrive/stage1_test/images',224))
# Out:
#  50%|█████     | 52/104 [00:57<01:08,  1.31s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-710906391f02> in <module>()
#      14     return IMG
#      15
# ---> 16 benign_train = np.array(Dataset_loader('/content/drive/MyDrive/ddsm/Benign/original/CC_Benign',224))
#      17 malign_train = np.array(Dataset_loader('/content/drive/MyDrive/ddsm/Cancer/original',224))
#      18 benign_test = np.array(Dataset_loader('/content/drive/MyDrive/Minita/image_val',224))
#
# <ipython-input-6-710906391f02> in Dataset_loader(DIR, RESIZE, sigmaX)
#       9             img = read(PATH)
#      10
# ---> 11             img = resize(img, (RESIZE,RESIZE,3))
#      12
#      13             IMG.append(np.array(img))
#
# /usr/local/lib/python3.7/dist-packages/skimage/transform/_warps.py in resize(image, output_shape, order, mode, cval, clip, preserve_range, anti_aliasing, anti_aliasing_sigma)
#     134
#     135         image = ndi.gaussian_filter(image, anti_aliasing_sigma,
# --> 136                                     cval=cval, mode=ndi_mode)
#     137
#     138     # 2-dimensional interpolation
#
# /usr/local/lib/python3.7/dist-packages/scipy/ndimage/filters.py in gaussian_filter(input, sigma, order, output, mode, cval, truncate)
#     297         for axis, sigma, order, mode in axes:
#     298             gaussian_filter1d(input, sigma, axis, order, output,
# --> 299                               mode, cval, truncate)
#     300             input = output
#     301     else:
#
# /usr/local/lib/python3.7/dist-packages/scipy/ndimage/filters.py in gaussian_filter1d(input, sigma, axis, order, output, mode, cval, truncate)
#     215     # Since we are calling correlate, not convolve, revert the kernel
#     216     weights = _gaussian_kernel1d(sigma, order, lw)[::-1]
# --> 217     return correlate1d(input, weights, axis, output, mode, cval, 0)
#     218
#     219
#
# /usr/local/lib/python3.7/dist-packages/scipy/ndimage/filters.py in correlate1d(input, weights, axis, output, mode, cval, origin)
#      93     mode = _ni_support._extend_mode_to_code(mode)
#      94     _nd_image.correlate1d(input, weights, axis, output, mode, cval,
# ---> 95                           origin)
#      96     return output
#      97
#
# KeyboardInterrupt:

# %%
# Create labels
benign_train_label = np.zeros(len(benign_train))
malign_train_label = np.ones(len(malign_train))
benign_test_label = np.zeros(len(benign_test))
malign_test_label = np.ones(len(malign_test))

# Merge data 
X_train = np.concatenate((benign_train, malign_train), axis = 0)
Y_train = np.concatenate((benign_train_label, malign_train_label), axis = 0)
X_test = np.concatenate((benign_test, malign_test), axis = 0)
Y_test = np.concatenate((benign_test_label, malign_test_label), axis = 0)

# Shuffle train data
s = np.arange(X_train.shape[0])
np.random.shuffle(s)
X_train = X_train[s]
Y_train = Y_train[s]

# Shuffle test data
s = np.arange(X_test.shape[0])
np.random.shuffle(s)
X_test = X_test[s]
Y_test = Y_test[s]

# To categorical
Y_train = to_categorical(Y_train, num_classes= 2)
Y_test = to_categorical(Y_test, num_classes= 2)

# %%
x_train, x_val, y_train, y_val = train_test_split(
    X_train, Y_train, 
    test_size=0.2, 
    random_state=11
)

# %%
# # Display first 15 mammograms, and how they are classified
w=60
h=40
fig=plt.figure(figsize=(15, 15))
columns = 5
rows = 3

for i in range(1, columns*rows +1):
    ax = fig.add_subplot(rows, columns, i)
    if np.argmax(Y_train[i]) == 0:
        ax.title.set_text('Benign')
    else:
        ax.title.set_text('Malignant')
    plt.imshow((x_train[i]).astype(np.uint8))
plt.show()

# %%
BATCH_SIZE = 16

# Using original generator
train_generator = ImageDataGenerator(
        zoom_range=2,  # set range for random zoom
        rotation_range = 90,
        horizontal_flip=True,  # randomly flip images
        vertical_flip=True,  # randomly flip images
    )

# %%
from tensorflow.keras.applications.inception_v3 import InceptionV3
base_model = InceptionV3(input_shape = (150, 150, 3), include_top = False, weights = 'imagenet')

# %%
for layer in base_model.layers:
    layer.trainable = False

# %%
from tensorflow.keras.optimizers import RMSprop

x = layers.Flatten()(base_model.output)
x = layers.Dense(1024, activation='relu')(x)
x = layers.Dropout(0.2)(x)
x = layers.Dense(1, activation='sigmoid')(x)

model = tf.keras.models.Model(base_model.input, x)

model.compile(optimizer = RMSprop(lr=0.0001), loss = 'binary_crossentropy', metrics = ['acc'])

# %%
inc_history = model.fit_generator(train_generator, validation_data = validation_generator, steps_per_epoch = 100, epochs = 10)

# %%
# Learning Rate Reducer
learn_control = ReduceLROnPlateau(monitor='val_loss', patience=5,
                                  verbose=1,factor=0.2, min_lr=1e-7)

# Checkpoint
filepath="/content/drive/MyDrive/Minita/weights.best.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='max')

# %%
print(x_train.shape)
print(y_train.shape)
# Out:
# (243, 224, 224, 3)
# (243, 2)

# %%
model.load_weights("/content/drive/MyDrive/Minita/weights.best.hdf5")
Y_val_pred = model.predict(x_val)
accuracy_score(np.argmax(y_val, axis=1), np.argmax(Y_val_pred, axis=1))
Y_pred = model.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-1cc88e4df756> in <module>()
# ----> 1 model.load_weights("/content/drive/MyDrive/Minita/weights.best.hdf5")
#       2 Y_val_pred = model.predict(x_val)
#       3 accuracy_score(np.argmax(y_val, axis=1), np.argmax(Y_val_pred, axis=1))
#       4 Y_pred = model.predict(X_test)
#
# NameError: name 'model' is not defined

# %%
tta_steps = 10
predictions = []

for i in tqdm(range(tta_steps)):
    preds = model.predict_generator(train_generator.flow(X_test, batch_size=BATCH_SIZE, shuffle=False),
                                    steps = len(X_test)/BATCH_SIZE)
    
    predictions.append(preds)
    gc.collect()
    
Y_pred_tta = np.mean(predictions, axis=0)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1905: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   warnings.warn('`Model.predict_generator` is deprecated and '
#
#  10%|█         | 1/10 [00:06<00:56,  6.22s/it]
#  20%|██        | 2/10 [00:09<00:41,  5.21s/it]
#  30%|███       | 3/10 [00:11<00:31,  4.50s/it]
#  40%|████      | 4/10 [00:14<00:24,  4.03s/it]
#  50%|█████     | 5/10 [00:17<00:18,  3.69s/it]
#  60%|██████    | 6/10 [00:20<00:13,  3.45s/it]
#  70%|███████   | 7/10 [00:23<00:09,  3.28s/it]
#  80%|████████  | 8/10 [00:26<00:06,  3.19s/it]
#  90%|█████████ | 9/10 [00:29<00:03,  3.10s/it]
# 100%|██████████| 10/10 [00:32<00:00,  3.23s/it]

# %%
from sklearn.metrics import confusion_matrix
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=55)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

cm = confusion_matrix(np.argmax(Y_test, axis=1), np.argmax(Y_pred, axis=1))

cm_plot_label =['benign', 'malignant']
plot_confusion_matrix(cm, cm_plot_label, title ='Confusion Matrix for Breast Cancer')
# Out:
# Confusion matrix, without normalization
# [[92 24]
#  [34 16]]

# %%
#Classification Report
from sklearn.metrics import classification_report
classification_report( np.argmax(Y_test, axis=1), np.argmax(Y_pred_tta, axis=1))
# Out:
# '              precision    recall  f1-score   support\n\n           0       0.71      0.64      0.67       116\n           1       0.32      0.40      0.36        50\n\n    accuracy                           0.57       166\n   macro avg       0.52      0.52      0.51       166\nweighted avg       0.59      0.57      0.58       166\n'

# %%
i=0
prop_class=[]
mis_class=[]

for i in range(len(Y_test)):
    if(np.argmax(Y_test[i])==np.argmax(Y_pred_tta[i])):
        prop_class.append(i)
    if(len(prop_class)==8):
        break

i=0
for i in range(len(Y_test)):
    if(not np.argmax(Y_test[i])==np.argmax(Y_pred_tta[i])):
        mis_class.append(i)
    if(len(mis_class)==10):
        break

# # Display first 8 images of benign
w=60
h=40
fig=plt.figure(figsize=(18, 10))
columns = 4
rows = 2

def Transfername(namecode):
    if namecode==0:
        return "Benign"
    else:
        return "Malignant"
    
for i in range(len(prop_class)):
    ax = fig.add_subplot(rows, columns, i+1)
    ax.set_title("Predicted result:"+ Transfername(np.argmax(Y_pred_tta[prop_class[i]]))
                       +"\n"+"Actual result: "+ Transfername(np.argmax(Y_test[prop_class[i]])))
    plt.imshow((X_test[prop_class[i]]).astype(np.uint8))
plt.show()

# %%
from sklearn.metrics import roc_auc_score, auc
from sklearn.metrics import roc_curve
roc_log = roc_auc_score(np.argmax(Y_test, axis=1), np.argmax(Y_pred_tta, axis=1))
false_positive_rate, true_positive_rate, threshold = roc_curve(np.argmax(Y_test, axis=1), np.argmax(Y_pred_tta, axis=1))
area_under_curve = auc(false_positive_rate, true_positive_rate)

plt.plot([0, 1], [0, 1], 'r--')
plt.plot(false_positive_rate, true_positive_rate, label='AUC = {:.3f}'.format(area_under_curve))
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve')
plt.legend(loc='best')
plt.show()
#plt.savefig(ROC_PLOT_FILE, bbox_inches='tight')
plt.close()

# %%
import os
model_name = 'AbnormalNormal.h5'
save_dir = 'pretrained_model' # pretrained_model # pred_model
# Save model and weights
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
model_path = os.path.join(save_dir, model_name)
model_final.save(model_path)
print('Saved trained model at %s ' % model_path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-1821ca05b3c2> in <module>()
#       6     os.makedirs(save_dir)
#       7 model_path = os.path.join(save_dir, model_name)
# ----> 8 model_final.save(model_path)
#       9 print('Saved trained model at %s ' % model_path)
#
# NameError: name 'model_final' is not defined

# %%
import keras
import cv2
import numpy as np
import matplotlib as plt
from google.colab.patches import cv2_imshow
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions

class Predict:

    def __init__(self, path, file):

        self.path = path
        self.file = file

    def load_model(self):
        '''
       Loading model.
        '''
        self.loaded_model = keras.models.load_model(self.path)
        return self.loaded_model

    def makepredictions(self):
        '''
      process the files, create your features and make predictions
        '''

        img = cv2.imread(self.file)

        img = cv2.resize(img, (224, 224))
        cv2_imshow(img)
        img = np.reshape(img, [1, 224, 224, 3])
        #print("File loaded and reshaped. The new shape is ", img.shape)
        print("Start predicting...")
        predictions = self.loaded_model.predict(img)

        #Converting output to human readable labels

        if (predictions.any() == 1):
          predictions = 'Malignant'
        elif (predictions.any() == 0):
          predictions = 'Benign'

        print( "Prediction completed: This is", predictions)



pred = Predict(
    path='/content/drive/MyDrive/Minita/weights.best.hdf5', 
    file='/content/drive/MyDrive/Dataset/Test_set/Abnormal/C_0404_1.LEFT_MLO.png'  ) 

pred.load_model()
pred.makepredictions()
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F706C7F00D0>
# Start predicting...
# Prediction completed: This is Malignant

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
